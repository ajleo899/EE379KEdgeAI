# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Blacksholes

# %%
time = []
watts = []
freq = []
max_temp = []

with open('log_q3.txt') as f:
    lines = f.readlines()
    time = [line.split()[0] for line in lines]
    watts = [line.split()[1] for line in lines]
    freq = [line.split()[2] for line in lines]
    max_temp = [line.split()[3] for line in lines]

# %%
time = time[41:961]
watts = watts[41:961]
freq = freq[41:961]
max_temp = max_temp[41:961]

# %%
for i in range(len(watts)):
    time[i] = float(time[i])
    watts[i] = float(watts[i])
    freq[i] = float(freq[i]) / 1000000
    max_temp[i] = float(max_temp[i])

# %%
print(max_temp)
# Out:
# [69.0, 72.0, 73.0, 74.0, 74.0, 75.0, 75.0, 76.0, 76.0, 76.0, 76.0, 76.0, 76.0, 77.0, 77.0, 77.0, 77.0, 77.0, 77.0, 77.0, 77.0, 77.0, 77.0, 77.0, 77.0, 78.0, 78.0, 78.0, 78.0, 78.0, 78.0, 78.0, 78.0, 78.0, 78.0, 78.0, 78.0, 78.0, 78.0, 78.0, 78.0, 78.0, 78.0, 78.0, 78.0, 78.0, 78.0, 78.0, 78.0, 78.0, 78.0, 78.0, 79.0, 78.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 81.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 79.0, 79.0, 79.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 80.0, 8
# ...

# %%
plt.plot(watts)
plt.title('System Power Over Time: Blacksholes')
plt.xlabel('Time (s)')
plt.ylabel('Power (W)')
plt.show()

# %%
plt.plot(freq)
plt.title('Frequency of Big Cores Over Time: Blacksholes')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (GHz)')
plt.show()

# %%
plt.plot(max_temp)
plt.title('System Max Big Temp Over Time: Blacksholes')
plt.xlabel('Time (s)')
plt.ylabel('Temp. (degrees celcius)')
plt.show()

# %% [markdown]
# # Blacksholes calculations

# %%
# average power 
average_power = sum(watts) / len(watts)
print(average_power)
# Out:
# 7.75823913043479

# %%
# average max temp
average_max_temp = sum(max_temp) / len(max_temp)
print(average_max_temp)
# Out:
# 82.67391304347827

# %%
# max temp
highest_temp = 0

for temp in max_temp:
    if temp > highest_temp:
        highest_temp = temp
        
print(highest_temp)
# Out:
# 88.0

# %%
# Energy
consumption = sum(watts)
print(consumption*0.2) # 0.2 is our sampling rate
# Out:
# 1427.5160000000014

# %% [markdown]
# # Bodytype

# %%
time = []
watts = []
freq = []
max_temp = []

with open('log_q3_2.txt') as f:
    lines = f.readlines()
    time = [line.split()[0] for line in lines]
    watts = [line.split()[1] for line in lines]
    freq = [line.split()[2] for line in lines]
    max_temp = [line.split()[3] for line in lines]
    

time = time[80:850]
watts = watts[80:850]
freq = freq[80:850]
max_temp = max_temp[80:850]


for i in range(len(watts)):
    time[i] = float(time[i])
    watts[i] = float(watts[i])
    freq[i] = float(freq[i]) / 1000000
    max_temp[i] = float(max_temp[i])

print(max_temp)

plt.plot(watts)
plt.title('System Power Over Time: Bodytrack')
plt.xlabel('Time (s)')
plt.ylabel('Power (W)')
plt.show()

plt.plot(freq)
plt.title('Frequency of Big Cores Over Time: Bodytrack')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (GHz)')
plt.show()

plt.plot(max_temp)
plt.title('System Max Big Temp Over Time: Bodytrack')
plt.xlabel('Time (s)')
plt.ylabel('Temp. (degrees celcius)')
plt.show()
# Out:
# [62.0, 72.0, 77.0, 81.0, 80.0, 83.0, 81.0, 81.0, 85.0, 80.0, 84.0, 87.0, 83.0, 87.0, 84.0, 85.0, 88.0, 81.0, 84.0, 85.0, 80.0, 84.0, 84.0, 81.0, 84.0, 83.0, 82.0, 84.0, 83.0, 84.0, 84.0, 82.0, 85.0, 84.0, 81.0, 85.0, 86.0, 82.0, 85.0, 84.0, 83.0, 86.0, 84.0, 84.0, 85.0, 82.0, 85.0, 85.0, 82.0, 85.0, 84.0, 82.0, 84.0, 85.0, 84.0, 84.0, 84.0, 84.0, 86.0, 83.0, 85.0, 85.0, 81.0, 83.0, 83.0, 81.0, 84.0, 86.0, 82.0, 83.0, 84.0, 82.0, 84.0, 85.0, 84.0, 86.0, 85.0, 85.0, 85.0, 82.0, 83.0, 84.0, 82.0, 83.0, 84.0, 82.0, 85.0, 86.0, 82.0, 86.0, 85.0, 81.0, 84.0, 85.0, 81.0, 84.0, 85.0, 83.0, 84.0, 85.0, 83.0, 86.0, 86.0, 84.0, 86.0, 84.0, 83.0, 84.0, 83.0, 84.0, 86.0, 83.0, 87.0, 86.0, 82.0, 85.0, 85.0, 81.0, 83.0, 84.0, 82.0, 84.0, 85.0, 83.0, 87.0, 85.0, 83.0, 85.0, 85.0, 82.0, 84.0, 84.0, 82.0, 84.0, 84.0, 83.0, 85.0, 83.0, 83.0, 85.0, 82.0, 83.0, 85.0, 83.0, 84.0, 85.0, 82.0, 84.0, 85.0, 81.0, 84.0, 84.0, 81.0, 84.0, 84.0, 81.0, 84.0, 85.0, 82.0, 86.0, 84.0, 83.0, 84.0, 84.0, 82.0, 84.0, 8
# ...

# %% [markdown]
# # Bodytrack calculations

# %%
# average power 
average_power = sum(watts) / len(watts)
print(average_power)
# Out:
# 8.5518103896104

# %%
# average max temp
average_max_temp = sum(max_temp) / len(max_temp)
print(average_max_temp)
# Out:
# 83.86233766233767

# %%
# max temp
highest_temp = 0

for temp in max_temp:
    if temp > highest_temp:
        highest_temp = temp
        
print(highest_temp)
# Out:
# 88.0

# %%
# Energy
consumption = sum(watts)
print(consumption*0.2) # 0.2 is our sampling rate
# Out:
# 1316.9788000000017
